# %% [markdown]
# <a href="https://colab.research.google.com/github/Anusha-Chittiraju123/NASSCOM/blob/main/WEEK%201/Writing_and_Using_Functions_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()
# Out:
# Hello! Welcome to Python Functions.

# %%
# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments
# Out:
# Hello, Alice!
# Hello, Bob!
