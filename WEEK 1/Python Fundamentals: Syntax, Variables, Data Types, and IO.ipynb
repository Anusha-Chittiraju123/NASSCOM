# %% [markdown]
# <a href="https://colab.research.google.com/github/Anusha-Chittiraju123/NASSCOM/blob/main/WEEK%201/Python%20Fundamentals%3A%20Syntax%2C%20Variables%2C%20Data%20Types%2C%20and%20IO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A simple Python statement
print("Hello, Python!")  # This is a comment

# Indentation defines blocks
if True:
    print("This is indented correctly.")
else:
    print("This won't run.")  # Not executed
# Out:
# Hello, Python!
# This is indented correctly.
